# %% [markdown]
# <a href="https://colab.research.google.com/github/kingmujeebmlan-beep/print/blob/main/print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('mujeeb')
# Out:
# umar
